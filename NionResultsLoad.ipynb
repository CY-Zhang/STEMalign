# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
path = '../../NionData/102121/'
idx = 1
Y = np.squeeze(np.load(path + 'FirstOrder_45mrad_500ms_' + str(idx) + '_Y.npy'))
Ronch = np.load(path + 'FirstOrder_45mrad_500ms_' + str(idx) + '_Ronchigram.npy')
plt.imshow(Ronch[20,:,:],cmap='gray')
plt.axis('off')
print(Y[10:])
print(Ronch.shape)
# Out:
# [0.75584139 0.89805695 0.87567511 0.80914357 0.87155166 0.91665572
#  0.91596127 0.87683339 0.92286685 0.87560697 0.91568713 0.88896231
#  0.93695144 0.93411051 0.92575698 0.91653034 0.91972007 0.91031994
#  0.91053727 0.94454876 0.94391853 0.91854812 0.91284943 0.92399327
#  0.9349976  0.91419022 0.91165869 0.9327101  0.91395672 0.77781928]
# (31, 128, 128)

# %%
path = '../../NionData/102121/'
fig, ax = plt.subplots(1, 1, figsize = [6, 3])
n = 5
for idx in range(n):
    Y = np.squeeze(np.load(path + 'FirstOrder_45mrad_500ms_' + str(idx) + '_Y.npy'))
    X = np.load(path + 'FirstOrder_45mrad_500ms_' + str(idx) + '_X.npy')
    Ronch = np.load(path + 'FirstOrder_45mrad_500ms_' + str(idx) + '_Ronchigram.npy')
    ax.plot(1-Y, c = 'C0', alpha = 1.0)
ax.set_ylabel('CNN prediction', fontsize = 16)
ax.set_xlabel('Iteration', fontsize = 16)
ax.tick_params(axis='both', labelsize=16)
ax.axvline(x=10, ls = '--', color = 'black')

# %%
path = '../../NionData/102121/'
fig, ax = plt.subplots(3, 1, figsize = [6, 10])
n = 5
for idx in range(n):
    Y = np.squeeze(np.load(path + 'FirstOrder_45mrad_500ms_' + str(idx) + '_Y.npy'))
    X = np.load(path + 'FirstOrder_45mrad_500ms_' + str(idx) + '_X.npy')
    Ronch = np.load(path + 'FirstOrder_45mrad_500ms_' + str(idx) + '_Ronchigram.npy')
    ax[0].plot((X[:,0] - 0.5) * 2, c = 'C0', alpha = 1.0)
    ax[1].plot((X[:,1] - 0.5) * 0.15, c = 'C1', alpha = 1.0)
    ax[2].plot((X[:,2] - 0.5) * 0.15, c = 'C2', alpha = 1.0)
    
ax[0].set_ylabel('C10 ($\mu$m)', fontsize = 16)
ax[1].set_ylabel('C12.x ($\mu$m)', fontsize = 16)
ax[2].set_ylabel('C12.y ($\mu$m)', fontsize = 16)
ax[2].set_xlabel('Iteration', fontsize = 16)
ax[0].tick_params(axis='both', labelsize=16)
ax[1].tick_params(axis='both', labelsize=16)
ax[2].tick_params(axis='both', labelsize=16)
ax[0].axvline(x=10, ls = '--', color = 'black')
ax[1].axvline(x=10, ls = '--', color = 'black')
ax[2].axvline(x=10, ls = '--', color = 'black')

# %%
X.shape
# Out:
# (40, 3)

# %%
# Y.shape
Y
# np.argmax(Y)
# Out:
# array([0.70983046, 0.5481717 , 0.39471924, 0.80165249, 0.47387743,
#        0.40663439, 0.44702578, 0.91941296, 0.40723079, 0.93309847,
#        0.81304535, 0.912251  , 0.9215325 , 0.86378115, 0.89840537,
#        0.86887562, 0.88488872, 0.8656276 , 0.88030323, 0.92186593,
#        0.92899273, 0.93074134, 0.89142099, 0.87301004, 0.91749658,
#        0.92180276, 0.91828503, 0.92907137, 0.93002723, 0.92439531,
#        0.91735163, 0.87494165, 0.89347447, 0.91725357, 0.92443313,
#        0.91817123, 0.9295812 , 0.92830932, 0.91600132, 0.91922358])

# %%
plt.imshow(Ronch[-12,:,:])
